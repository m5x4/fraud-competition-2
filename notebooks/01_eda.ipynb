# %%
# import packages for data processing
import pandas as pd
import numpy as np
from sklearn.preprocessing import PowerTransformer

# import packages for data visualisation
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# import packages for statistical analysis
from scipy import stats
from scipy.stats import chi2_contingency

# import packages for model building


# set display options
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/raw/train.csv')

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   text  \
# 0                              The width of the block represents the importance of the feature for the specific row. The wider the block is, the more important the feature is to push the predicted probability. The model predicted the case 1 user correctly as a depressed user. Their mention of “划破” and low percentage of positive words mentioned largely affect the model to predict it as a depressed user. The model predicted the case 2 user correctly as a normal user. The fact that they didn’t mention “共青团员” and “划破” and the high value of percentage of positive words mentioned push the model to predict it as a normal user. To sum up the feature importance section, different from the assumption and the word frequency analysis in the exploratory data analysis part, frequents words mentioned by depressed users such as “痛苦”,“抑郁” are not the important features in the XGBoost model.
# 1     Quality of constructed questions are typically improved over time with more experience in question asking. Our model targets to help users who are less familiar with the posting questions or facing difficulties in framing the questions in the right manner, to improve their question posts. While absolute scores provide an indication of the question quality, it will be difficult for less experienced users to interpret the meaning of the score considering the infinite score range. As such, unlike the existing studies on Stack Overflow that predict scores as a regression problem, our project will be approaching the business problem as a classification problem and advise users on whether their draft posts are considered “Good”, “Normal” or “Bad”. Having 3 categories is meant to provide users a relative sense of how much improvement is needed for their draft question posts.
# 2                                                                                                            The sentiment score of a loan description is determined using the NLTK's sentiment intensity analyzer following several text pre-processing steps. These steps involve converting text to lowercase, lemmatization, and the removal of borrower names, numbers, punctuation, the irrelevant '&lt;br&gt;' text, stop words, and extra white spaces. Once the sentiment score is computed, it is incorporated as an additional feature in the analysis. Notably, it has been observed that loan descriptions displaying more negative sentiments, such as those suggesting borrower desperation, are associated with higher funding rates. This suggests that potential lenders might be inclined to fund loans perceived as more urgent or critical, based on the sentiment expressed in the descriptions.
# 3                                                                                                                                                                                                                                                                                                                                                   In conclusion, we have built machine learning models seeking to predict the readmission rate of diabetic patients and found that the trajectory of patient care before and after the hospitalization of the diabetic patient is key in determining the readmission rate, specifically in relation to the level and nature of care that the patient requires. The key metrics used were F1 score and accuracy score. While we used F1-score as an evaluation metric with 0.5 threshold, this threshold can be changed depending on our goal of real business cases.
# 4  The following models were trained on the processed training data, and their performance were evaluated against each other to determine which has the best fit: • Linear Model: o Logistic Regression o Naïve Bayes • Tree-based Ensemble o Random Forest o XG Boost • Neural Network o LSTM Linear models were chosen as they are simple and fast training models which would give us a baseline comparison to more complex models. Random Forest makes use of bagging and feature randomness when building each individual tree to create a forest of trees which are uncorrelated – the predictions of these forests of trees increase the accuracy as compared to using just a single tree. Further, XGBoost was chosen as it makes use of boosting where the errors are minimized through gradient descent. LSTM is considered for its ability to learn sequential data together with longer-term dependencies.
#
#    label
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0

# %%
df.isna().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
df.columns.tolist()
# Out:
# ['text', 'label']
